# %% [markdown]
# # Notebook for filtering down models to study
#
# Exclude if:
# - doesn't complete training
# - doesn't reach accuracy threshold

# %%
import os, scipy.io 
import numpy as np 
# %matplotlib ipympl
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import axes3d

import sys

sys.path.append('/home/nuttidalab/Documents/renee/spikeRNN/analysis/utils')
import load_data as ld

import pickle as pk
# Out:
# 2026-04-23 12:32:40.785275: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-23 12:32:40.794231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-04-23 12:32:40.803384: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-04-23 12:32:40.806148: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-23 12:32:40.813770: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-23 12:32:41.350398: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import glob

def find_files(path, pattern):
    """
    Find all files matching the given glob pattern in the specified path
    Args:
        path (str): path to directory
        pattern (str): glob pattern (e.g., '*.xlsx', '*_sorted_new.mat')
    Returns:
        list of file paths
    """
    return glob.glob(os.path.join(path, pattern))

# %%
model_dir = '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5'

model_names = find_files(model_dir, '*N_1000*.mat')
print(len(model_names))
print(model_names)
# Out:
# 28
# ['/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163426.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_044205.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174533.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_162727.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155940.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_151908.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_061957.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_014713.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_150948.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_052959.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_140925.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_025058.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_16_232416.mat']

# %% [markdown]
# ### training trials filter

# %%
# move the models that don't finish training to the "old" folder
perfs = []
train_trials = []
for i, model_path in enumerate(model_names):
    # model_path = os.path.join(model_dir, model_name)
    model_name = os.path.basename(model_path)
    model_data = scipy.io.loadmat(model_path)
    perfs.append(model_data['eval_perfs'][0])
    train_trials.append(model_data['tr'][0][0])
    print(f'Model: {model_name}, Test perf: {perfs[i]}, Train trials: {train_trials[i]}')
    
    if train_trials[i] == 39999:
        print(f'Model {model_name} did not finish training. Moving to old folder.')
        old_path = os.path.join(model_dir, 'old', model_name)
        os.rename(model_path, old_path)
        
print('Done moving unfinished models.')
# Out:
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163426.mat, Test perf: [0.96 0.82], Train trials: 23501
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450.mat, Test perf: [0.98 0.83], Train trials: 24401
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_14_044205.mat, Test perf: [0.96 0.85], Train trials: 23201
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441.mat, Test perf: [0.97 0.87], Train trials: 21401
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174533.mat, Test perf: [0.97 0.98], Train trials: 32201
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229.mat, Test perf: [0.96 0.87], Train trials: 26401
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257.mat, Test perf: [0.96 0.86], Train trials: 27501
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_162727.mat, Test perf: [0.86 0.86], Train trials: 39999
# Model Task_sternberg_N_1000_Jitter_5_3_2026_04_17_162727.mat did not finish training. Moving to old folder.
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549.mat, Test perf: [0.96 0.88], Train trials: 32001
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155940.mat, Test perf: [0.96 0.86], Train trials: 26301
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_151908.mat, Test perf: [0.82 0.82], Train trials: 39999
# Model Task_sternberg_N_1000_Jitter_5_3_2026_04_17_151908.mat did not finish training. Moving to old folder.
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_14_061957.mat, Test perf: [0.96 0.93], Train trials: 25301
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047.mat, Test perf: [0.96 0.91], Train trials: 34101
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_14_014713.mat, Test perf: [0.96 0.87], Train trials: 25101
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328.mat, Test perf: [0.96 0.81], Train trials: 24601
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128.mat, Test perf: [0.98 0.85], Train trials: 31801
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420.mat, Test perf: [0.96 0.85], Train trials: 23901
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_150948.mat, Test perf: [0.57 0.65], Train trials: 39999
# Model Task_sternberg_N_1000_Jitter_5_3_2026_04_17_150948.mat did not finish training. Moving to old folder.
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830.mat, Test perf: [0.96 0.86], Train trials: 24901
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_14_052959.mat, Test perf: [0.96 0.86], Train trials: 38101
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628.mat, Test perf: [0.97 0.91], Train trials: 29901
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511.mat, Test perf: [0.97 0.89], Train trials: 26001
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352.mat, Test perf: [0.96 0.94], Train trials: 38801
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_140925.mat, Test perf: [0.96 0.89], Train trials: 19601
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144.mat, Test perf: [0.97 0.85], Train trials: 27701
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_14_025058.mat, Test perf: [0.96 0.93], Train trials: 29801
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957.mat, Test perf: [0.96 0.84], Train trials: 24001
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_16_232416.mat, Test perf: [0.95 0.84], Train trials: 39999
# Model Task_sternberg_N_1000_Jitter_5_3_2026_04_16_232416.mat did not finish training. Moving to old folder.
# Done moving unfinished models.

# %%
model_dir = '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5'

model_names = find_files(model_dir, '*N_1000*.mat')
print(len(model_names))
print(model_names)
# Out:
# 24
# ['/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163426.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_044205.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174533.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155940.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_061957.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_014713.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_052959.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_140925.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_025058.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957.mat']

# %% [markdown]
# ### performance filter

# %% [markdown]
# as a filter, start generating some data for a longer delay (200) and see which models we want to generate more data for

# %%
def generate_input_stim_sternberg_stims(settings, stim_ids, max_load=3):
    # use stims to specify which channels to activate for the memory set, 
    # instead of randomly choosing them
    # use inf to indicate non-activated channels for lower loads

    T = int(settings['T'])
    stim_on = int(settings['stim_on'])
    stim_dur = int(settings['stim_dur'])
    delay = int(settings['delay'])
    load = (~np.isinf(stim_ids)).sum() - 1 # count number of non-inf values in stim_ids to determine load
    # load = settings['load'] # int for number of items to remember
    
    n_channels = 4

    # Initialize u
    u = np.zeros((n_channels, T))
    
    # Sternberg task
    for i, i_chan in enumerate(stim_ids[:load]):
        i_chan = int(i_chan) # convert from float to int
        if i == 0:
            u[i_chan, stim_on:stim_on+stim_dur] = 1
            ending_idx = stim_on+stim_dur
        else: # 0 bc no separation btwn stimuli
            u[i_chan, ending_idx+0:ending_idx+stim_dur+0] = 1
            ending_idx = ending_idx+stim_dur+0
    
    probe = int(stim_ids[max_load])
    u[probe, ending_idx+delay:ending_idx+delay+stim_dur] = 1
    label = 1 if stim_ids[max_load] in stim_ids[:load] else -1

    return u, label, stim_ids

# %%
from itertools import permutations, product

def get_all_stim_combos():
    # generate all possible stim combinations for the memory set and probe
    # use inf to indicate non-activated channels for lower loads
    
    values = [0, 1, 2, 3]

    # Part 1: all permutations of [0,1,2,3]
    first_three = list(permutations(values, 3))  # 4P3 = 24

    # Combine with column 3 (can repeat anything)
    full = [(a, b, c, d) for (a, b, c) in first_three for d in values]

    perm_part = np.array(full)

    # Part 2: [x, inf, inf, y]
    inf = np.inf

    middle_inf_part = np.array(
        [[x, inf, inf, y] for x, y in product(values, repeat=2)],
        dtype=float
    )

    # Combine
    result = np.vstack([perm_part, middle_inf_part])
    
    return result

# %%
# NOT PARALLELIZED VERSION
sys.path.append('/home/nuttidalab/Documents/renee/spikeRNN/rate')
import model

import tqdm

n_trials = 50
eval_amp_threshold = 0.7
matches = [0, 1] # 0 for mismatch, 1 for match
loads = [1, 3] # number of items to remember
model_list = model_names

trial_stims = get_all_stim_combos()
trial_stims_test_idxs = []
# pick subset of stim combos to run through for testing

# take all load 1
load1 = np.where(trial_stims[:,1] == np.inf)[0]
trial_stims_test_idxs.extend(load1)

# take some load 3
load3 = np.where(trial_stims[:,1] != np.inf)[0]
match_idxs = [i for i in range(len(load3)) if trial_stims[load3[i], -1] in trial_stims[load3[i], :3]]
load3_match = load3[match_idxs]
mismatch_idxs = [i for i in range(len(load3)) if trial_stims[load3[i], -1] not in trial_stims[load3[i], :3]]
load3_mismatch = load3[mismatch_idxs]
trial_stims_test_idxs.extend(np.random.choice(load3_match, size=16, replace=False))
trial_stims_test_idxs.extend(np.random.choice(load3_mismatch, size=16, replace=False))

print(f'Total stim combos to test: {len(trial_stims_test_idxs)}')

trial_stims_test = trial_stims[trial_stims_test_idxs]

max_load = trial_stims.shape[1] - 1

# delay200
settings = {
        'T': 450, # trial duration (in steps)
        'stim_on': 50, # input stim onset (in steps)
        'stim_dur': 25, # input stim duration (in steps)
        'delay': 200, # delay b/w the two stimuli (in steps)
        'DeltaT': 1, # sampling rate
        'taus': 20, # decay time-constants (in steps)
        'fs': 200,
        'task': 'sternberg', # task name
        'load': 1,
        }

for n_model, model_path in enumerate(model_list):
    model_name = os.path.basename(model_path)
    print(model_name)
    output_dir = model_dir + '/' + model_name[:-4] + '/'
    # os.makedirs(output_dir, exist_ok=True)
    
    # check if saved neural_dict and bhv_dict already
    if os.path.exists(os.path.join(output_dir, f'neural_dict_delay{settings["delay"]}.pkl')) and os.path.exists(os.path.join(output_dir, f'bhv_dict_delay{settings["delay"]}.pkl')):
        print(f'skipping {model_name}, already saved')
        continue
    
    loads = []
    perfs = []
    
    # time this loop to see how long it takes to run through all stim combos for one model
    pbar = tqdm.tqdm(trial_stims_test)
    for stim_ids in pbar:
        # print(stim_ids)

        # compute load from inf mask (same logic as before)
        load = (~np.isinf(stim_ids)).sum() - 1

        local_settings = settings.copy()
        local_settings['load'] = int(load)

        resp_onset = (
            local_settings['stim_on']
            + load * local_settings['stim_dur']
            + local_settings['delay']
            + 10
        )

        u, label, stim_ids_used = generate_input_stim_sternberg_stims(
                local_settings,
                stim_ids,
                max_load=max_load
            )
        
        _, r, o, epsp = model.eval_tf(
                model_dir=f'{model_dir}/{model_name}',
                settings=local_settings,
                u=u,
                calc_epsp=True
            )

        # Behavioral performance
        if label == 1:
            perf = int(np.max(o[resp_onset:]) > eval_amp_threshold)
        else:
            perf = int(np.min(o[resp_onset:]) < -eval_amp_threshold)
        perfs.append(perf)
        loads.append(load)
    
    print(f'Model: {model_name}, Average performance across all stim combos: {np.mean(perfs)}')
    
    if np.mean(perfs) < 0.5:
        print(f'Model {model_name} has poor performance. Moving to low perf folder.')
        lowperf_path = os.path.join(model_dir, 'low_perf', model_name)
        os.rename(model_path, lowperf_path)
# Out:
# Total stim combos to test: 48
# Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163426.mat
# 100%|██████████| 48/48 [04:14<00:00,  5.31s/it]
# Model: Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163426.mat, Average performance across all stim combos: 0.4375
# Model Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163426.mat has poor performance. Moving to low perf folder.
# Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450.mat
#   8%|▊         | 4/48 [00:24<04:24,  6.02s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 86
#      73 resp_onset = (
#      74     local_settings['stim_on']
#      75     + load * local_settings['stim_dur']
#      76     + local_settings['delay']
#      77     + 10
#      78 )
#      80 u, label, stim_ids_used = generate_input_stim_sternberg_stims(
#      81         local_settings,
#      82         stim_ids,
#      83         max_load=max_load
#      84     )
# ---> 86 _, r, o, epsp = model.eval_tf(
#      87         model_dir=f'{model_dir}/{model_name}',
#      88         settings=local_settings,
#      89         u=u,
#      90         calc_epsp=True
#      91     )
#      93 # Behavioral performance
#      94 if label == 1:
#
# File ~/Documents/renee/spikeRNN/rate/model.py:736, in eval_tf(model_dir, settings, u, lesion, calc_epsp)
#     732     w = np.multiply(w, lesion_mask)
#     734 for t in range(1, T):
#     735     # next_x is [N x 1]
# --> 736     ww = np.matmul(w, m)
#     737     ww = np.multiply(ww, som_m)
#     739     # next_x = (1 - DeltaT/tau)*x[:, t-1] + \
#     740             # (DeltaT/tau)*(np.matmul(ww, r[:, t-1]) + \
#     741             # np.matmul(var['w_in'], u[:, t-1])) + \
#     742             # np.random.randn(N, )/10
#
# KeyboardInterrupt:

# %%
model_dir = '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5'

model_names = find_files(model_dir, '*N_1000*.mat')
print(len(model_names))
print(model_names)
# Out:
# 23
# ['/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_044205.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174533.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155940.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_061957.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_014713.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_052959.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_140925.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_025058.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957.mat']

# %%
import os
import sys
import numpy as np
from joblib import Parallel, delayed
import tqdm

sys.path.append('/home/nuttidalab/Documents/renee/spikeRNN/rate')
import model

eval_amp_threshold = 0.7

# Build this once in the parent process
trial_stims = get_all_stim_combos()
trial_stims_test_idxs = []

# take all load 1
load1 = np.where(trial_stims[:, 1] == np.inf)[0]
trial_stims_test_idxs.extend(load1)

# take some load 3
load3 = np.where(trial_stims[:, 1] != np.inf)[0]
match_idxs = [i for i in range(len(load3)) if trial_stims[load3[i], -1] in trial_stims[load3[i], :3]]
mismatch_idxs = [i for i in range(len(load3)) if trial_stims[load3[i], -1] not in trial_stims[load3[i], :3]]

load3_match = load3[match_idxs]
load3_mismatch = load3[mismatch_idxs]

rng = np.random.default_rng(0)  # reproducible
trial_stims_test_idxs.extend(rng.choice(load3_match, size=16, replace=False))
trial_stims_test_idxs.extend(rng.choice(load3_mismatch, size=16, replace=False))

trial_stims_test = trial_stims[trial_stims_test_idxs]
max_load = trial_stims.shape[1] - 1

settings = {
    'T': 450,
    'stim_on': 50,
    'stim_dur': 25,
    'delay': 200,
    'DeltaT': 1,
    'taus': 20,
    'fs': 200,
    'task': 'sternberg',
    'load': 1,
}


def evaluate_one_model(model_path, model_dir, trial_stims_test, max_load, settings, eval_amp_threshold):
    model_name = os.path.basename(model_path)
    output_dir = os.path.join(model_dir, model_name[:-4])

    neural_path = os.path.join(output_dir, f'neural_dict_delay{settings["delay"]}.pkl')
    bhv_path = os.path.join(output_dir, f'bhv_dict_delay{settings["delay"]}.pkl')

    if os.path.exists(neural_path) and os.path.exists(bhv_path):
        return {
            "model_name": model_name,
            "status": "skipped",
            "mean_perf": None,
        }

    loads = []
    perfs = []

    for stim_ids in trial_stims_test:
        load = (~np.isinf(stim_ids)).sum() - 1

        local_settings = settings.copy()
        local_settings['load'] = int(load)

        resp_onset = (
            local_settings['stim_on']
            + load * local_settings['stim_dur']
            + local_settings['delay']
            + 10
        )

        u, label, stim_ids_used = generate_input_stim_sternberg_stims(
            local_settings,
            stim_ids,
            max_load=max_load
        )

        _, r, o, epsp = model.eval_tf(
            model_dir=os.path.join(model_dir, model_name),
            settings=local_settings,
            u=u,
            calc_epsp=True
        )

        if label == 1:
            perf = int(np.max(o[resp_onset:]) > eval_amp_threshold)
        else:
            perf = int(np.min(o[resp_onset:]) < -eval_amp_threshold)

        perfs.append(perf)
        loads.append(load)

    mean_perf = float(np.mean(perfs))

    if mean_perf < 0.5:
        lowperf_dir = os.path.join(model_dir, 'low_perf')
        os.makedirs(lowperf_dir, exist_ok=True)
        lowperf_path = os.path.join(lowperf_dir, model_name)

        if os.path.exists(model_path) and not os.path.exists(lowperf_path):
            os.rename(model_path, lowperf_path)

        status = "moved_low_perf"
    else:
        status = "done"

    return {
        "model_name": model_name,
        "status": status,
        "mean_perf": mean_perf,
    }


results = Parallel(n_jobs=4, backend="loky", verbose=10)(
    delayed(evaluate_one_model)(
        model_path,
        model_dir,
        trial_stims_test,
        max_load,
        settings,
        eval_amp_threshold
    )
    for model_path in model_names
)

for res in results:
    print(res)
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# 2026-04-23 13:21:14.855540: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-23 13:21:14.864409: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-23 13:21:14.865052: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-04-23 13:21:14.873943: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-04-23 13:21:14.875347: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-04-23 13:21:14.878411: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-23 13:21:14.884475: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-04-23 13:21:14.886447: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-23 13:21:14.887446: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-23 13:21:14.895181: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-23 13:21:14.899514: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-23 13:21:14.910012: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-04-23 13:21:14.920359: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-04-23 13:21:14.923214: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-23 13:21:14.931106: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-23 13:21:14.936994: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-23 13:21:14.947086: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-04-23 13:21:14.957579: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-04-23 13:21:14.960834: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-23 13:21:14.968858: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-23 13:21:15.335364: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-04-23 13:21:15.357478: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-04-23 13:21:15.365011: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-04-23 13:21:15.412088: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/nuttidalab/miniconda3/envs/rnn_test/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /home/nuttidalab/miniconda3/envs/rnn_test/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /home/nuttidalab/miniconda3/envs/rnn_test/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /home/nuttidalab/miniconda3/envs/rnn_test/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=4)]: Done  19 out of  23 | elapsed: 16.7min remaining:  3.5min
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450.mat', 'status': 'done', 'mean_perf': 0.6041666666666666}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_044205.mat', 'status': 'skipped', 'mean_perf': None}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441.mat', 'status': 'skipped', 'mean_perf': None}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174533.mat', 'status': 'done', 'mean_perf': 0.8333333333333334}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229.mat', 'status': 'done', 'mean_perf': 0.6875}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257.mat', 'status': 'done', 'mean_perf': 0.6875}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549.mat', 'status': 'done', 'mean_perf': 0.6041666666666666}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155940.mat', 'status': 'done', 'mean_perf': 0.75}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_061957.mat', 'status': 'skipped', 'mean_perf': None}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047.mat', 'status': 'done', 'mean_perf': 0.6458333333333334}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_014713.mat', 'status': 'skipped', 'mean_perf': None}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328.mat', 'status': 'done', 'mean_perf': 0.6458333333333334}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128.mat', 'status': 'done', 'mean_perf': 0.6666666666666666}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420.mat', 'status': 'done', 'mean_perf': 0.5833333333333334}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830.mat', 'status': 'done', 'mean_perf': 0.6458333333333334}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_052959.mat', 'status': 'skipped', 'mean_perf': None}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628.mat', 'status': 'skipped', 'mean_perf': None}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511.mat', 'status': 'done', 'mean_perf': 0.7291666666666666}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352.mat', 'status': 'done', 'mean_perf': 0.6666666666666666}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_140925.mat', 'status': 'done', 'mean_perf': 0.5833333333333334}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144.mat', 'status': 'done', 'mean_perf': 0.6458333333333334}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_025058.mat', 'status': 'skipped', 'mean_perf': None}
# {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957.mat', 'status': 'done', 'mean_perf': 0.6875}
# [Parallel(n_jobs=4)]: Done  23 out of  23 | elapsed: 21.8min finished

# %%
results
# Out:
# [{'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450.mat',
#   'status': 'done',
#   'mean_perf': 0.6041666666666666},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_044205.mat',
#   'status': 'skipped',
#   'mean_perf': None},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441.mat',
#   'status': 'skipped',
#   'mean_perf': None},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174533.mat',
#   'status': 'done',
#   'mean_perf': 0.8333333333333334},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229.mat',
#   'status': 'done',
#   'mean_perf': 0.6875},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257.mat',
#   'status': 'done',
#   'mean_perf': 0.6875},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549.mat',
#   'status': 'done',
#   'mean_perf': 0.6041666666666666},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155940.mat',
#   'status': 'done',
#   'mean_perf': 0.75},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_061957.mat',
#   'status': 'skipped',
#   'mean_perf': None},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047.mat',
#   'status': 'done',
#   'mean_perf': 0.6458333333333334},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_014713.mat',
#   'status': 'skipped',
#   'mean_perf': None},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328.mat',
#   'status': 'done',
#   'mean_perf': 0.6458333333333334},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128.mat',
#   'status': 'done',
#   'mean_perf': 0.6666666666666666},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420.mat',
#   'status': 'done',
#   'mean_perf': 0.5833333333333334},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830.mat',
#   'status': 'done',
#   'mean_perf': 0.6458333333333334},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_052959.mat',
#   'status': 'skipped',
#   'mean_perf': None},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628.mat',
#   'status': 'skipped',
#   'mean_perf': None},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511.mat',
#   'status': 'done',
#   'mean_perf': 0.7291666666666666},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352.mat',
#   'status': 'done',
#   'mean_perf': 0.6666666666666666},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_140925.mat',
#   'status': 'done',
#   'mean_perf': 0.5833333333333334},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144.mat',
#   'status': 'done',
#   'mean_perf': 0.6458333333333334},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_025058.mat',
#   'status': 'skipped',
#   'mean_perf': None},
#  {'model_name': 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957.mat',
#   'status': 'done',
#   'mean_perf': 0.6875}]

# %%
model_dir = '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5'

model_names = find_files(model_dir, '*N_1000*.mat')
print(len(model_names))
print(model_names)
# Out:
# 23
# ['/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_044205.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174533.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155940.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_061957.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_014713.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_052959.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_140925.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_025058.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957.mat']
