# %% [markdown]
# # Generate data from rate model
#
# firing rates, LFP, behavior
#
# run after filtering down the models using filter_models_multiload.ipynb (in 0_behavior/1_model_performance folder)

# %% [markdown]
# ### Balance stimulus combinations mode (default)
# python analysis/generate_rate_data_multiload.py generate-data \
#   --model-dir /home/nuttidalab/Documents/renee/sternberg/multiload_1_2_3  \
#   --mode balance_stims --n-repetitions 3
#
# conda run -n tf_gpu python analysis/generate_rate_data_multiload.py generate-data \
#   --model-dir /home/nuttidalab/Documents/renee/sternberg/multiload_1_2_3 \
#   --mode balance_stims \
#   --n-repetitions 3 \
#   --backend torch \
#   --device cuda \
#   --workers 1
#
# ### Balance match/mismatch mode [old]
# python analysis/generate_rate_data.py generate-data \
#   --model-dir /home/nuttidalab/Documents/renee/sternberg/interleaved_0.5 \
#   --mode balance_match --n-trials 50 --loads 1 3
#
# conda run -n tf_gpu python analysis/generate_rate_data.py generate-data \
#   --model-dir /home/nuttidalab/Documents/renee/sternberg/interleaved_0.5 \
#   --mode balance_match \
#   --n-trials 50 \
#   --loads 1 3 \
#   --backend torch \
#   --device cuda \
#   --workers 1
#
#
# ### in notebook
# import generate_rate_data as grd
#
# grd.generate_data(
#     model_dir="/home/nuttidalab/Documents/renee/sternberg/multiload_1_2_3",
#     pattern="*N_1000*.mat",
#     n_repetitions=3,          # used by balance_stims
#     eval_amp_threshold=0.7,
#     workers=1,
#     backend="torch",
#     device="cuda",
#     overwrite=False,
#     mode="balance_stims",     # or "balance_match"
#     n_trials=50,              # used by balance_match
#     loads=[1, 3],             # used by balance_match
# )

# %%
# %matplotlib inline
import sys
sys.path.append('/home/nuttidalab/Documents/renee/spikeRNN/analysis')
import generate_rate_data_multiload as grdm

sys.path.append('/home/nuttidalab/Documents/renee/spikeRNN/analysis/utils')
import load_data as ld
# Out:
# 2026-06-03 17:50:07.962860: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-03 17:50:07.971391: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-06-03 17:50:07.980239: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-06-03 17:50:07.982946: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-06-03 17:50:07.990211: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-06-03 17:50:08.482883: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### first time — with balanced stims

# %%
import importlib
importlib.reload(grdm)
model_dir = "/home/nuttidalab/Documents/renee/sternberg/multiload_1_2_3"
grdm.plot_quick_behavior(model_dir=model_dir)
grdm.plot_behavior_boxplots(model_dir=model_dir)
# Out:
# [0.96       0.93333333 0.85333333]
# [0.98666667 0.94666667 0.89333333]
# [0.97333333 0.93333333 0.93333333]
# (3, 3) (3, 3)
# 3 [1, 2, 3]

# %% [markdown]
# #### old / unused, but could adapt

# %%
grd.move_low_perf_models(model_dir=model_dir, threshold=0.7, actually_move=False)

# %%
grd.move_low_perf_models(model_dir=model_dir, threshold=0.7, actually_move=True)
# Out:
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441.mat with delay=200 perf [0.7916667 0.5520833] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_025058.mat with delay=200 perf [0.7291667 0.6354167] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_044205.mat with delay=200 perf [0.8541667 0.6006944] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628.mat with delay=200 perf [0.625     0.6354167] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_052959.mat with delay=200 perf [0.75      0.6666667] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_061957.mat with delay=200 perf [0.75      0.6909722] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328.mat with delay=200 perf [0.7708333  0.47569445] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352.mat with delay=200 perf [0.625     0.6979167] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_140925.mat with delay=200 perf [0.7083333 0.6145833] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450.mat with delay=200 perf [0.7708333 0.5243056] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257.mat with delay=200 perf [0.8125    0.4340278] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511.mat with delay=200 perf [0.6875    0.6597222] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047.mat with delay=200 perf [0.6875    0.5347222] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155940.mat with delay=200 perf [0.8333333 0.6423611] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128.mat with delay=200 perf [0.6875  0.40625] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144.mat with delay=200 perf [0.6875  0.59375] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420.mat with delay=200 perf [0.625     0.4236111] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549.mat with delay=200 perf [0.75      0.5277778] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830.mat with delay=200 perf [0.6458333 0.5555556] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957.mat with delay=200 perf [0.6875    0.4097222] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229.mat with delay=200 perf [0.7083333 0.6145833] to low_perf folder

# %%
# get the remaining models
model_dir = '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5' 

model_names = ld.find_files(model_dir, '*N_1000*.mat')
print(len(model_names))
print(model_names)
# Out:
# 24
# ['/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163426.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_044205.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174533.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155940.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_061957.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_014713.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_052959.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_140925.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_14_025058.mat', '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5/Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957.mat']

# %%
# write something to bring the .mat files back to the original folder if needed

# get names of all folders in directory 
import os
folder_names = [f for f in os.listdir(model_dir) if os.path.isdir(os.path.join(model_dir, f))]
print(folder_names)
# Out:
# ['Task_sternberg_N_1000_Jitter_5_3_2026_04_17_140925', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257', 'shorter_tau', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155940', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_044205', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_025058', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174533', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_052959', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_014713', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352', 'low_perf', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163426', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328', 'old', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549', 'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_061957']

# %%
folder_names
# Out:
# ['Task_sternberg_N_1000_Jitter_5_3_2026_04_17_140925',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155940',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_044205',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_025058',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174533',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_052959',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_014713',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163426',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549',
#  'Task_sternberg_N_1000_Jitter_5_3_2026_04_14_061957']

# %%
# bring back the .mat files from low_perf folder to original folder if needed
low_perf_dir = os.path.join(model_dir, 'low_perf')
if os.path.exists(low_perf_dir):
    folder_names = [f for f in os.listdir(model_dir) if os.path.isdir(os.path.join(model_dir, f)) and f.startswith('Task_')]
    for model_name in folder_names:
        model_path = os.path.join(low_perf_dir, f"{model_name}.mat")
        if os.path.exists(model_path):
            new_path = os.path.join(model_dir, f"{model_name}.mat")
            print(f"Moving {model_name} back to original folder")
            os.rename(model_path, new_path)
# Out:
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155940 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_044205 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_025058 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_052959 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163426 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549 back to original folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_061957 back to original folder

# %% [markdown]
# ### back to balanced match/mismatch

# %% [markdown]
# grd.plot_quick_behavior(model_dir=model_dir, mode="balance_match", include_models=["Task_001", "Task_014.mat"])
# grd.plot_behavior_boxplots(model_dir=model_dir, mode="balance_stims", include_models=["Task_001"])

# %%
import importlib
importlib.reload(grd)

model_dir = "/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5"

grd.plot_quick_behavior(model_dir=model_dir, mode="balance_match", 
                        include_models=None)

# %%
importlib.reload(grd)
model_names = grd.move_low_perf_models(model_dir=model_dir, threshold=0.7, 
                                       mode="balance_match", actually_move=False)

print(len(model_names))
# Out:
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441.mat with delay=200 perf [0.86 0.65] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628.mat with delay=200 perf [0.64 0.69] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328.mat with delay=200 perf [0.74 0.6 ] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352.mat with delay=200 perf [0.76 0.65] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450.mat with delay=200 perf [0.74 0.66] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257.mat with delay=200 perf [0.62 0.64] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511.mat with delay=200 perf [0.67 0.76] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047.mat with delay=200 perf [0.66 0.68] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128.mat with delay=200 perf [0.54 0.62] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144.mat with delay=200 perf [0.69 0.68] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163426.mat with delay=200 perf [0.56 0.34] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420.mat with delay=200 perf [0.67 0.45] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549.mat with delay=200 perf [0.63 0.63] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830.mat with delay=200 perf [0.79 0.57] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957.mat with delay=200 perf [0.76 0.57] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229.mat with delay=200 perf [0.81 0.64] to low_perf folder
# 8

# %%
importlib.reload(grd)
model_names = grd.move_low_perf_models(model_dir=model_dir, threshold=0.7, 
                                       mode="balance_match", actually_move=True)

print(len(model_names))
# Out:
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_013441.mat with delay=200 perf [0.86 0.65] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_14_051628.mat with delay=200 perf [0.64 0.69] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_16_152328.mat with delay=200 perf [0.74 0.6 ] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_071352.mat with delay=200 perf [0.76 0.65] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_142450.mat with delay=200 perf [0.74 0.66] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143257.mat with delay=200 perf [0.62 0.64] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_143511.mat with delay=200 perf [0.67 0.76] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_155047.mat with delay=200 perf [0.66 0.68] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_161128.mat with delay=200 perf [0.54 0.62] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163144.mat with delay=200 perf [0.69 0.68] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_163426.mat with delay=200 perf [0.56 0.34] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_171420.mat with delay=200 perf [0.67 0.45] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_172549.mat with delay=200 perf [0.63 0.63] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173830.mat with delay=200 perf [0.79 0.57] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_173957.mat with delay=200 perf [0.76 0.57] to low_perf folder
# Moving Task_sternberg_N_1000_Jitter_5_3_2026_04_17_174229.mat with delay=200 perf [0.81 0.64] to low_perf folder
# 8

# %%
import importlib
importlib.reload(grd)

model_dir = "/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5"

grd.plot_quick_behavior(model_dir=model_dir, mode="balance_match", 
                        include_models=None)

# %%
grd.plot_behavior_boxplots(model_dir=model_dir, mode="balance_match", include_models=None)
