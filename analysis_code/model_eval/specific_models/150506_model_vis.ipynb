# %% [markdown]
# # Example model visualization

# %%
import os, scipy.io 
import numpy as np 
import matplotlib.pyplot as plt 

import sys
sys.path.append('/home/nuttidalab/Documents/renee/spikeRNN/rate/')

import model
# Out:
# 2026-04-09 15:21:05.468029: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-09 15:21:05.477293: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-04-09 15:21:05.486800: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-04-09 15:21:05.489629: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-04-09 15:21:05.497805: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-09 15:21:05.981169: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/nuttidalab/miniconda3/envs/rnn_test/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# ## one model

# %% [markdown]
# ### load model

# %%
model_dir = '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5'
model_fname = 'Task_sternberg_N_1000_Jitter_5_3_2026_03_17_150506.mat'
mat_data = scipy.io.loadmat(os.path.join(model_dir, model_fname))

# %%
for keys in mat_data.keys():
    print(keys)
# Out:
# __header__
# __version__
# __globals__
# x0
# r0
# w0
# taus_gaus0
# w_in0
# u
# o
# w
# x
# target
# w_out
# r
# m
# som_m
# N
# exc
# inh
# w_in
# b_out
# som_N
# losses
# taus
# eval_perf_mean
# eval_loss_mean
# eval_os
# eval_labels
# taus_gaus
# tr
# activation
# stim_on_tr
# stim_dur_tr
# p_low
# eval_perfs
# eval_perfs_all
# load
# delay_tr
# T_tr
# all_perfs
# opt_scaling_factor
# scaling_factors

# %%
eval_perfs_all = mat_data['eval_perfs_all']
eval_perfs_all = eval_perfs_all.squeeze()
print(mat_data['tr'])
print(eval_perfs_all.shape)
# Out:
# [[12501]]
# (126, 2)

# %%
plt.figure(figsize=(10,5))
plt.plot(eval_perfs_all[:,0], label='load1')
plt.plot(eval_perfs_all[:,1], label='load3')
plt.xlabel('training epoch (every 100 trials)')
plt.ylabel('performance')
plt.legend()
plt.title('Model performance across training')
plt.show()

# %%
# plot training loss

losses = mat_data['losses'][0]
plt.figure(figsize=(16,4))
plt.plot(losses[:mat_data['tr'][0][0]])
plt.xlabel('trials')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
plt.show()

# %% [markdown]
# ### model eval

# %%
# low load, short delay
settings = {
            'T': 250, # trial duration (in steps)
            'stim_on': 50, # input stim onset (in steps)
            'stim_dur': 25, # input stim duration (in steps)
            'delay': 10, # delay b/w sample and test (in steps)
            'DeltaT': 1, # sampling rated
            'load': 1,
            }

resp_onset = settings['stim_on'] + settings['stim_dur']*(settings['load']+1) + settings['delay'] + 10
eval_amp_threshold = 0.7

n_trials = 20
fig, axs = plt.subplots(4, 5, figsize=(16, 12), sharex=True)
axs = axs.flatten()
for j in range(n_trials):
    u_high, label = model.generate_input_stim_sternberg(settings)
    x, r, o, _ = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=u_high)

    axs[j].plot(o)
    for i in range(u_high.shape[0]):
        axs[j].plot(u_high[i,:])
    
    if label == 1:
        if np.max(o[resp_onset:]) > eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    else:
        if np.max(o[resp_onset:]) < -eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    axs[j].set_title(f'output for stim label: {label}', color=title_color)
    axs[j].legend(['output','stim'])
plt.show()

# %%
# high load, long delay
settings = {
            'T': 250, # trial duration (in steps)
            'stim_on': 50, # input stim onset (in steps)
            'stim_dur': 25, # input stim duration (in steps)
            'delay': 10, # delay b/w sample and test (in steps)
            'DeltaT': 1, # sampling rated
            'load': 3, # initialize with load 1, but will alternate with 3
            }

resp_onset = settings['stim_on'] + settings['stim_dur']*(settings['load']+1) + settings['delay'] + 10
eval_amp_threshold = 0.7

n_trials = 20
fig, axs = plt.subplots(4, 5, figsize=(16, 12), sharex=True)
axs = axs.flatten()
for j in range(n_trials):
    u_high, label = model.generate_input_stim_sternberg(settings)
    x, r, o, _ = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=u_high)

    axs[j].plot(o)
    for i in range(u_high.shape[0]):
        axs[j].plot(u_high[i,:])
        
    if label == 1:
        if np.max(o[resp_onset:]) > eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    else:
        if np.max(o[resp_onset:]) < -eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    axs[j].set_title(f'output for stim label: {label}', color=title_color)
    axs[j].legend(['output','stim'])
plt.show()

# %%
# low load, long delay
settings = {
            'T': 350, # trial duration (in steps)
            'stim_on': 50, # input stim onset (in steps)
            'stim_dur': 25, # input stim duration (in steps)
            'delay': 100, # delay b/w sample and test (in steps)
            'DeltaT': 1, # sampling rated
            'load': 1,
            }

resp_onset = settings['stim_on'] + settings['stim_dur']*(settings['load']+1) + settings['delay'] + 10
eval_amp_threshold = 0.7

n_trials = 20
fig, axs = plt.subplots(4, 5, figsize=(16, 12), sharex=True)
axs = axs.flatten()
for j in range(n_trials):
    u_high, label = model.generate_input_stim_sternberg(settings)
    x, r, o, _ = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=u_high)

    axs[j].plot(o)
    for i in range(u_high.shape[0]):
        axs[j].plot(u_high[i,:])
    
    if label == 1:
        if np.max(o[resp_onset:]) > eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    else:
        if np.max(o[resp_onset:]) < -eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    axs[j].set_title(f'output for stim label: {label}', color=title_color)
    axs[j].legend(['output','stim'])
plt.show()

# %%
# high load, long delay
settings = {
            'T': 350, # trial duration (in steps)
            'stim_on': 50, # input stim onset (in steps)
            'stim_dur': 25, # input stim duration (in steps)
            'delay': 100, # delay b/w sample and test (in steps)
            'DeltaT': 1, # sampling rated
            'load': 3, # initialize with load 1, but will alternate with 3
            }

resp_onset = settings['stim_on'] + settings['stim_dur']*(settings['load']+1) + settings['delay'] + 10
eval_amp_threshold = 0.7

n_trials = 20
fig, axs = plt.subplots(4, 5, figsize=(16, 12), sharex=True)
axs = axs.flatten()
for j in range(n_trials):
    u_high, label = model.generate_input_stim_sternberg(settings)
    x, r, o, _ = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=u_high)

    axs[j].plot(o)
    for i in range(u_high.shape[0]):
        axs[j].plot(u_high[i,:])
        
    if label == 1:
        if np.max(o[resp_onset:]) > eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    else:
        if np.max(o[resp_onset:]) < -eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    axs[j].set_title(f'output for stim label: {label}', color=title_color)
    axs[j].legend(['output','stim'])
plt.show()

# %%
# model eval on 100 random trials

n_trials = 100
resp_onset = settings['stim_on'] + settings['stim_dur']
eval_amp_threshold = 0.7
eval_perf = np.zeros(n_trials)

for i in range(n_trials):
    eval_u, eval_label = model.generate_input_stim_sternberg(settings)
    _, _, eval_o = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=eval_u)
    if eval_label == 1:
        if np.max(eval_o[resp_onset:]) > eval_amp_threshold:
            eval_perf[i] = 1
    else:
        if np.max(np.abs(eval_o[resp_onset:])) < 0.3:
            eval_perf[i] = 1

eval_perf_mean = np.nanmean(eval_perf)
print("Performance: %.2f"%(eval_perf_mean))
# Out:
# Performance: 1.00

# %% [markdown]
# ## another model

# %%
model_dir = '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5'
model_fname = 'Task_sternberg_N_1000_Jitter_5_3_2026_04_08_212410.mat'
mat_data = scipy.io.loadmat(os.path.join(model_dir, model_fname))

# %%
eval_perfs_all = mat_data['eval_perfs_all']
eval_perfs_all = eval_perfs_all.squeeze()
print(mat_data['tr'])
print(eval_perfs_all.shape)
# Out:
# [[11501]]
# (116, 2)

# %%
plt.figure(figsize=(10,5))
plt.plot(eval_perfs_all[:,0], label='load1')
plt.plot(eval_perfs_all[:,1], label='load3')
plt.xlabel('training epoch (every 100 trials)')
plt.ylabel('performance')
plt.legend()
plt.title('Model performance across training')
plt.show()

# %%
# plot training loss

losses = mat_data['losses'][0]
plt.figure(figsize=(16,4))
plt.plot(losses[:mat_data['tr'][0][0]])
plt.xlabel('trials')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
plt.show()

# %% [markdown]
# ### model eval

# %%
# low load, short delay
settings = {
            'T': 250, # trial duration (in steps)
            'stim_on': 50, # input stim onset (in steps)
            'stim_dur': 25, # input stim duration (in steps)
            'delay': 10, # delay b/w sample and test (in steps)
            'DeltaT': 1, # sampling rated
            'load': 1,
            }

resp_onset = settings['stim_on'] + settings['stim_dur']*(settings['load']+1) + settings['delay'] + 10
eval_amp_threshold = 0.7

n_trials = 20
fig, axs = plt.subplots(4, 5, figsize=(16, 12), sharex=True)
axs = axs.flatten()
for j in range(n_trials):
    u_high, label = model.generate_input_stim_sternberg(settings)
    x, r, o, _ = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=u_high)

    axs[j].plot(o)
    for i in range(u_high.shape[0]):
        axs[j].plot(u_high[i,:])
    
    if label == 1:
        if np.max(o[resp_onset:]) > eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    else:
        if np.min(o[resp_onset:]) < -eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    axs[j].set_title(f'output for stim label: {label}', color=title_color)
    axs[j].legend(['output','stim'])
plt.show()

# %%
# high load, short delay
settings = {
            'T': 250, # trial duration (in steps)
            'stim_on': 50, # input stim onset (in steps)
            'stim_dur': 25, # input stim duration (in steps)
            'delay': 10, # delay b/w sample and test (in steps)
            'DeltaT': 1, # sampling rated
            'load': 3, # initialize with load 1, but will alternate with 3
            }

resp_onset = settings['stim_on'] + settings['stim_dur']*(settings['load']+1) + settings['delay'] + 10
eval_amp_threshold = 0.7

n_trials = 20
fig, axs = plt.subplots(4, 5, figsize=(16, 12), sharex=True)
axs = axs.flatten()
for j in range(n_trials):
    u_high, label = model.generate_input_stim_sternberg(settings)
    x, r, o, _ = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=u_high)

    axs[j].plot(o)
    for i in range(u_high.shape[0]):
        axs[j].plot(u_high[i,:])
        
    if label == 1:
        if np.max(o[resp_onset:]) > eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    else:
        if np.min(o[resp_onset:]) < -eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    axs[j].set_title(f'output for stim label: {label}', color=title_color)
    axs[j].legend(['output','stim'])
plt.show()

# %%
# low load, long delay
settings = {
            'T': 350, # trial duration (in steps)
            'stim_on': 50, # input stim onset (in steps)
            'stim_dur': 25, # input stim duration (in steps)
            'delay': 100, # delay b/w sample and test (in steps)
            'DeltaT': 1, # sampling rated
            'load': 1,
            }

resp_onset = settings['stim_on'] + settings['stim_dur']*(settings['load']+1) + settings['delay'] + 10
eval_amp_threshold = 0.7

n_trials = 20
fig, axs = plt.subplots(4, 5, figsize=(16, 12), sharex=True)
axs = axs.flatten()
for j in range(n_trials):
    u_high, label = model.generate_input_stim_sternberg(settings)
    x, r, o, _ = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=u_high)

    axs[j].plot(o)
    for i in range(u_high.shape[0]):
        axs[j].plot(u_high[i,:])
    
    if label == 1:
        if np.max(o[resp_onset:]) > eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    else:
        if np.min(o[resp_onset:]) < -eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    axs[j].set_title(f'output for stim label: {label}', color=title_color)
    axs[j].legend(['output','stim'])
plt.show()

# %%
# high load, long delay
settings = {
            'T': 350, # trial duration (in steps)
            'stim_on': 50, # input stim onset (in steps)
            'stim_dur': 25, # input stim duration (in steps)
            'delay': 100, # delay b/w sample and test (in steps)
            'DeltaT': 1, # sampling rated
            'load': 3, # initialize with load 1, but will alternate with 3
            }

resp_onset = settings['stim_on'] + settings['stim_dur']*(settings['load']+1) + settings['delay'] + 10
eval_amp_threshold = 0.7

n_trials = 20
fig, axs = plt.subplots(4, 5, figsize=(16, 12), sharex=True)
axs = axs.flatten()
for j in range(n_trials):
    u_high, label = model.generate_input_stim_sternberg(settings)
    x, r, o, _ = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=u_high)

    axs[j].plot(o)
    for i in range(u_high.shape[0]):
        axs[j].plot(u_high[i,:])
        
    if label == 1:
        if np.max(o[resp_onset:]) > eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    else:
        if np.min(o[resp_onset:]) < -eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    axs[j].set_title(f'output for stim label: {label}', color=title_color)
    axs[j].legend(['output','stim'])
plt.show()

# %% [markdown]
# ## another model

# %%
model_dir = '/home/nuttidalab/Documents/renee/sternberg/interleaved_0.5'
model_fname = 'Task_sternberg_N_1000_Jitter_5_3_2026_03_17_150506.mat'
mat_data = scipy.io.loadmat(os.path.join(model_dir, model_fname))

# %%
for keys in mat_data.keys():
    print(keys)
# Out:
# __header__
# __version__
# __globals__
# x0
# r0
# w0
# taus_gaus0
# w_in0
# u
# o
# w
# x
# target
# w_out
# r
# m
# som_m
# N
# exc
# inh
# w_in
# b_out
# som_N
# losses
# taus
# eval_perf_mean
# eval_loss_mean
# eval_os
# eval_labels
# taus_gaus
# tr
# activation
# stim_on_tr
# stim_dur_tr
# p_low
# eval_perfs
# eval_perfs_all
# load
# delay_tr
# T_tr
# all_perfs
# opt_scaling_factor
# scaling_factors

# %%
eval_perfs_all = mat_data['eval_perfs_all']
eval_perfs_all = eval_perfs_all.squeeze()
print(mat_data['tr'])
print(eval_perfs_all.shape)
# Out:
# [[12501]]
# (126, 2)

# %%
plt.figure(figsize=(10,5))
plt.plot(eval_perfs_all[:,0], label='load1')
plt.plot(eval_perfs_all[:,1], label='load3')
plt.xlabel('training epoch (every 100 trials)')
plt.ylabel('performance')
plt.legend()
plt.title('Model performance across training')
plt.show()

# %%
# plot training loss

losses = mat_data['losses'][0]
plt.figure(figsize=(16,4))
plt.plot(losses[:mat_data['tr'][0][0]])
plt.xlabel('trials')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
plt.show()

# %% [markdown]
# ### model eval

# %%
# low load, short delay
settings = {
            'T': 250, # trial duration (in steps)
            'stim_on': 50, # input stim onset (in steps)
            'stim_dur': 25, # input stim duration (in steps)
            'delay': 10, # delay b/w sample and test (in steps)
            'DeltaT': 1, # sampling rated
            'load': 1,
            }

resp_onset = settings['stim_on'] + settings['stim_dur']*(settings['load']+1) + settings['delay'] + 10
eval_amp_threshold = 0.7

n_trials = 20
fig, axs = plt.subplots(4, 5, figsize=(16, 12), sharex=True)
axs = axs.flatten()
for j in range(n_trials):
    u_high, label = model.generate_input_stim_sternberg(settings)
    x, r, o, _ = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=u_high)

    axs[j].plot(o)
    for i in range(u_high.shape[0]):
        axs[j].plot(u_high[i,:])
    
    if label == 1:
        if np.max(o[resp_onset:]) > eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    else:
        if np.max(o[resp_onset:]) < -eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    axs[j].set_title(f'output for stim label: {label}', color=title_color)
    axs[j].legend(['output','stim'])
plt.show()

# %%
# high load, long delay
settings = {
            'T': 250, # trial duration (in steps)
            'stim_on': 50, # input stim onset (in steps)
            'stim_dur': 25, # input stim duration (in steps)
            'delay': 10, # delay b/w sample and test (in steps)
            'DeltaT': 1, # sampling rated
            'load': 3, # initialize with load 1, but will alternate with 3
            }

resp_onset = settings['stim_on'] + settings['stim_dur']*(settings['load']+1) + settings['delay'] + 10
eval_amp_threshold = 0.7

n_trials = 20
fig, axs = plt.subplots(4, 5, figsize=(16, 12), sharex=True)
axs = axs.flatten()
for j in range(n_trials):
    u_high, label = model.generate_input_stim_sternberg(settings)
    x, r, o, _ = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=u_high)

    axs[j].plot(o)
    for i in range(u_high.shape[0]):
        axs[j].plot(u_high[i,:])
        
    if label == 1:
        if np.max(o[resp_onset:]) > eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    else:
        if np.max(o[resp_onset:]) < -eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    axs[j].set_title(f'output for stim label: {label}', color=title_color)
    axs[j].legend(['output','stim'])
plt.show()

# %%
# low load, long delay
settings = {
            'T': 350, # trial duration (in steps)
            'stim_on': 50, # input stim onset (in steps)
            'stim_dur': 25, # input stim duration (in steps)
            'delay': 100, # delay b/w sample and test (in steps)
            'DeltaT': 1, # sampling rated
            'load': 1,
            }

resp_onset = settings['stim_on'] + settings['stim_dur']*(settings['load']+1) + settings['delay'] + 10
eval_amp_threshold = 0.7

n_trials = 20
fig, axs = plt.subplots(4, 5, figsize=(16, 12), sharex=True)
axs = axs.flatten()
for j in range(n_trials):
    u_high, label = model.generate_input_stim_sternberg(settings)
    x, r, o, _ = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=u_high)

    axs[j].plot(o)
    for i in range(u_high.shape[0]):
        axs[j].plot(u_high[i,:])
    
    if label == 1:
        if np.max(o[resp_onset:]) > eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    else:
        if np.max(o[resp_onset:]) < -eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    axs[j].set_title(f'output for stim label: {label}', color=title_color)
    axs[j].legend(['output','stim'])
plt.show()

# %%
# high load, long delay
settings = {
            'T': 350, # trial duration (in steps)
            'stim_on': 50, # input stim onset (in steps)
            'stim_dur': 25, # input stim duration (in steps)
            'delay': 100, # delay b/w sample and test (in steps)
            'DeltaT': 1, # sampling rated
            'load': 3, # initialize with load 1, but will alternate with 3
            }

resp_onset = settings['stim_on'] + settings['stim_dur']*(settings['load']+1) + settings['delay'] + 10
eval_amp_threshold = 0.7

n_trials = 20
fig, axs = plt.subplots(4, 5, figsize=(16, 12), sharex=True)
axs = axs.flatten()
for j in range(n_trials):
    u_high, label = model.generate_input_stim_sternberg(settings)
    x, r, o, _ = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=u_high)

    axs[j].plot(o)
    for i in range(u_high.shape[0]):
        axs[j].plot(u_high[i,:])
        
    if label == 1:
        if np.max(o[resp_onset:]) > eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    else:
        if np.max(o[resp_onset:]) < -eval_amp_threshold:
            title_color = 'green'
        else:
            title_color = 'red'
    axs[j].set_title(f'output for stim label: {label}', color=title_color)
    axs[j].legend(['output','stim'])
plt.show()

# %%
# model eval on 100 random trials

n_trials = 100
resp_onset = settings['stim_on'] + settings['stim_dur']
eval_amp_threshold = 0.7
eval_perf = np.zeros(n_trials)

for i in range(n_trials):
    eval_u, eval_label = model.generate_input_stim_sternberg(settings)
    _, _, eval_o = model.eval_tf(model_dir=f'{model_dir}/{model_fname}', settings=settings, u=eval_u)
    if eval_label == 1:
        if np.max(eval_o[resp_onset:]) > eval_amp_threshold:
            eval_perf[i] = 1
    else:
        if np.max(np.abs(eval_o[resp_onset:])) < 0.3:
            eval_perf[i] = 1

eval_perf_mean = np.nanmean(eval_perf)
print("Performance: %.2f"%(eval_perf_mean))
# Out:
# Performance: 1.00

# %% [markdown]
# ### plotting model firing rates r, and synaptic current x

# %%
mat_data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'x0', 'r0', 'w0', 'taus_gaus0', 'w_in0', 'u', 'o', 'w', 'x', 'target', 'w_out', 'r', 'm', 'som_m', 'N', 'exc', 'inh', 'w_in', 'b_out', 'som_N', 'losses', 'taus', 'eval_perf_mean', 'eval_loss_mean', 'eval_os', 'eval_labels', 'taus_gaus', 'tr', 'activation'])

# %%
r = mat_data['r']
x = mat_data['x']
print(r.shape)
print(x.shape)
# Out:
# (200, 200, 1)
# (200, 200, 1)

# %%
exc = mat_data['exc']
exc_ind = np.where(exc == 1)[0]
inh = mat_data['inh']
inh_ind = np.where(inh == 1)[0]
print(inh_ind)
# Out:
# [  4   8   9  14  16  19  21  31  40  42  44  51  59  62  67  70  71  75
#   76  77  80  88  92 101 102 103 107 121 123 124 129 130 132 133 138 142
#  153 154 159 174 178 180 187 192 193 195]

# %% [markdown]
# ### Trajectory plots

# %%
from sklearn.decomposition import PCA

# %%
r = mat_data['r'][:,:,0]
r.shape
# Out:
# (200, 200)

# %%
resp_onset = settings['stim_on'] + settings['stim_dur']

# %% [markdown]
# X (r): time x neurons
#
# U: time x n_components
#
# S: n_components
#
# Vt: n_components x neurons

# %%
# X = USVt

pca = PCA(n_components=100).fit(r)
r_U = pca.transform(r)
r_S = pca.singular_values_
r_Vt = pca.components_

print(r_U.shape)
print(r_S.shape)
print(r_Vt.shape)
# Out:
# (200, 100)
# (100,)
# (100, 200)

# %%
fig,axs = plt.subplots(1,2,figsize=(16,4))
im1 = axs[0].imshow(r[:,exc_ind].T,cmap='binary',vmin=0, vmax=1)
axs[0].set_xlabel('time')
axs[0].set_ylabel('neurons')
axs[0].set_title('excitatory neurons')
fig.colorbar(im1)

im2 = axs[1].imshow(r[:,inh_ind].T,cmap='binary',vmin=0, vmax=1)
axs[1].set_xlabel('time')
axs[1].set_ylabel('neurons')
axs[1].set_title('inhibitory neurons')
fig.colorbar(im2)

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
# %matplotlib inline 
# %matplotlib widget

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.scatter(r_U[:,0], r_U[:,1], r_U[:,2], c=range(200))
ax.plot3D(r_U[:,0], r_U[:,1], r_U[:,2], 'gray')
ax.scatter(r_U[resp_onset,0], r_U[resp_onset,1], r_U[resp_onset,2], c='r')
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('neural fr trajectories for single trial of Go/No-Go task')
plt.show()
