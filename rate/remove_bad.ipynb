# %% [markdown]
# # Remove models that did not learn

# %%
import os, scipy.io 
import numpy as np 
# %matplotlib ipympl
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import axes3d
import pickle as pk
import sys
import importlib


sys.path.append('/home/nuttidalab/Documents/renee/spikeRNN/analysis/utils')
import load_data as ld
# Out:
# 2025-10-27 02:08:36.184529: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-27 02:08:36.194549: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-27 02:08:36.204857: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-27 02:08:36.208072: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-27 02:08:36.217052: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-27 02:08:36.809937: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model_dir = '/home/nuttidalab/Documents/renee/jitter_models/models/xor/P_rec_0.2_Taus_4.0_25.0'
model_list = ld.find_files_keywords(model_dir, ['Jitter_10_2', '.mat'])
# remove directories 
model_list = [m.split('/')[-1] for m in model_list]
model_list.sort()

# print(model_list)
print(len(model_list))

perfs = []
train_trials = []
for i, model_name in enumerate(model_list):
    model_path = os.path.join(model_dir, model_name)
    model_data = scipy.io.loadmat(model_path)
    perfs.append(model_data['eval_perf_mean'][0][0])
    train_trials.append(model_data['tr'][0][0])
    print(f'Model: {model_name}, Test perf: {perfs[i]}, Train trials: {train_trials[i]}')
# Out:
# 22
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_104619.mat, Test perf: 0.98, Train trials: 4401
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_104646.mat, Test perf: 0.96, Train trials: 4201
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_105047.mat, Test perf: 0.98, Train trials: 8101
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_105127.mat, Test perf: 1.0, Train trials: 4701
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_105135.mat, Test perf: 0.96, Train trials: 4401
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_105319.mat, Test perf: 0.96, Train trials: 11101
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_105403.mat, Test perf: 1.0, Train trials: 2901
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_105541.mat, Test perf: 1.0, Train trials: 3801
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_105725.mat, Test perf: 0.98, Train trials: 5501
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_105909.mat, Test perf: 0.98, Train trials: 5601
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_110006.mat, Test perf: 0.99, Train trials: 5701
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_110110.mat, Test perf: 0.97, Train trials: 5101
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_110136.mat, Test perf: 0.97, Train trials: 3901
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_110226.mat, Test perf: 0.96, Train trials: 3001
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_110531.mat, Test perf: 0.98, Train trials: 3701
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_110757.mat, Test perf: 0.98, Train trials: 5501
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_110932.mat, Test perf: 1.0, Train trials: 10301
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_111225.mat, Test perf: 1.0, Train trials: 3101
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_123826.mat, Test perf: 0.99, Train trials: 6301
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_124200.mat, Test perf: 0.97, Train trials: 4001
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_124530.mat, Test perf: 1.0, Train trials: 4301
# Model: Task_xor_N_200_Jitter_10_2_2025_10_24_124912.mat, Test perf: 0.97, Train trials: 4101
