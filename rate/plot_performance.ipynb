# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import scipy.io
import pandas as pd


models_types = ['good_models','bad_models']
lesion_connections_list = ['no lesion', 'I - I','E - E','E - I','I - E']
models_dir = '/scratch/spikeRNN/models/DMS_OSF/' # dir where all models are located

# Initialize lists to hold data
all_performance = []
all_model_types = []
all_lesion_connections = []

# Loop through the model types and gather data
for models_type in models_types:
    model_performance = scipy.io.loadmat(f'{models_dir}{models_type}/{models_type}_performance.mat')['eval_perf_mean']
    
    # Assuming model_performance is structured as (n_models, n_lesions)
    for lesion_idx in range(model_performance.shape[1]):
        all_performance.extend(model_performance[:, lesion_idx])  # Collect performance scores for the lesion type
        all_model_types.extend([models_type] * model_performance.shape[0])  # Add model type for each score
        all_lesion_connections.extend([lesion_connections_list[lesion_idx]] * model_performance.shape[0])  # Add lesion type for each score

# Create a DataFrame for easier plotting
data = pd.DataFrame({
    'Model Type': all_model_types,
    'Lesion Connection': all_lesion_connections,
    'Performance': all_performance
})

# Create a grouped boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Lesion Connection', y='Performance', hue='Model Type', 
            data=data, width=0.3, dodge=True) 
plt.title('Model Performance by Lesion Connection and Model Type')
plt.xlabel('Lesion Connection')
plt.ylabel('Performance')
plt.legend(title='Model Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import scipy.io
import pandas as pd


models_types = ['good_models','bad_models']
lesion_connections_list = ['no lesion', 'I - I','E - E','E - I','I - E']
models_dir = '/home/nuttidalab/Documents/spikeRNN/models/DMS_OSF/' # dir where all models are located

# Initialize lists to hold data
all_performance = []
all_model_types = []
all_lesion_connections = []

# Loop through the model types and gather data
for models_type in models_types:
    model_performance = scipy.io.loadmat(f'{models_dir}{models_type}/{models_type}_performance200.mat')['eval_perf_mean']
    
    # Assuming model_performance is structured as (n_models, n_lesions)
    for lesion_idx in range(model_performance.shape[1]):
        all_performance.extend(model_performance[:, lesion_idx])  # Collect performance scores for the lesion type
        all_model_types.extend([models_type] * model_performance.shape[0])  # Add model type for each score
        all_lesion_connections.extend([lesion_connections_list[lesion_idx]] * model_performance.shape[0])  # Add lesion type for each score

# Create a DataFrame for easier plotting
data = pd.DataFrame({
    'Model Type': all_model_types,
    'Lesion Connection': all_lesion_connections,
    'Performance': all_performance
})

# Create a grouped boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Lesion Connection', y='Performance', hue='Model Type', 
            data=data, width=0.3, dodge=True) 
plt.title('Model Performance by Lesion Connection and Model Type, Delay 1000ms')
plt.xlabel('Lesion Connection')
plt.ylabel('Performance')
plt.legend(title='Model Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import scipy.io
import pandas as pd


models_types = ['good_models','bad_models']
lesion_connections_list = ['no lesion', 'I - I','E - E','E - I','I - E']
models_dir = '/home/nuttidalab/Documents/spikeRNN/models/DMS_OSF/' # dir where all models are located

# Initialize lists to hold data
all_performance = []
all_model_types = []
all_lesion_connections = []

# Loop through the model types and gather data
for models_type in models_types:
    model_performance = scipy.io.loadmat(f'{models_dir}{models_type}/{models_type}_performance250.mat')['eval_perf_mean']
    
    # Assuming model_performance is structured as (n_models, n_lesions)
    for lesion_idx in range(model_performance.shape[1]):
        all_performance.extend(model_performance[:, lesion_idx])  # Collect performance scores for the lesion type
        all_model_types.extend([models_type] * model_performance.shape[0])  # Add model type for each score
        all_lesion_connections.extend([lesion_connections_list[lesion_idx]] * model_performance.shape[0])  # Add lesion type for each score

# Create a DataFrame for easier plotting
data = pd.DataFrame({
    'Model Type': all_model_types,
    'Lesion Connection': all_lesion_connections,
    'Performance': all_performance
})

# Create a grouped boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Lesion Connection', y='Performance', hue='Model Type', 
            data=data, width=0.3, dodge=True) 
plt.title('Model Performance by Lesion Connection and Model Type, Delay 1250ms')
plt.xlabel('Lesion Connection')
plt.ylabel('Performance')
plt.legend(title='Model Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import scipy.io
import pandas as pd


models_types = ['good_models','bad_models']
lesion_connections_list = ['no lesion', 'I - I','E - E','E - I','I - E']
models_dir = '/home/nuttidalab/Documents/spikeRNN/models/DMS_OSF/' # dir where all models are located

# Initialize lists to hold data
all_performance = []
all_model_types = []
all_lesion_connections = []

# Loop through the model types and gather data
for models_type in models_types:
    model_performance = scipy.io.loadmat(f'{models_dir}{models_type}/{models_type}_performance400.mat')['eval_perf_mean_all']
    
    # Assuming model_performance is structured as (n_models, n_lesions)
    for lesion_idx in range(model_performance.shape[1]):
        all_performance.extend(model_performance[:, lesion_idx])  # Collect performance scores for the lesion type
        all_model_types.extend([models_type] * model_performance.shape[0])  # Add model type for each score
        all_lesion_connections.extend([lesion_connections_list[lesion_idx]] * model_performance.shape[0])  # Add lesion type for each score

# Create a DataFrame for easier plotting
data = pd.DataFrame({
    'Model Type': all_model_types,
    'Lesion Connection': all_lesion_connections,
    'Performance': all_performance
})

# Create a grouped boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Lesion Connection', y='Performance', hue='Model Type', 
            data=data, width=0.3, dodge=True) 
plt.title('Model Performance by Lesion Connection and Model Type, Delay 2000ms')
plt.xlabel('Lesion Connection')
plt.ylabel('Performance')
plt.legend(title='Model Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot Synaptic Weight Matrices

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import scipy.io
import pandas as pd


models_types = ['good_models','bad_models']
connection_types_list = ['I - I','I - E','E - I','E - E']
models_dir = '/home/nuttidalab/Documents/spikeRNN/models/DMS_OSF/' # dir where all models are located

# Initialize lists to hold data
all_weights = []
all_model_types = []
all_connection_types = []

# Loop through the model types and gather data
for models_type in models_types:
    mean_synaptic_w = scipy.io.loadmat(f'{models_dir}{models_type}/mean_synaptic_w.mat')['mean_synaptic_w']
    
    # Assuming mean_synaptic_w is structured as (n_models, n_connection_types)
    for connection_idx in range(mean_synaptic_w.shape[1]):
        all_weights.extend(mean_synaptic_w[:, connection_idx])  # Collect weight scores for the connection type
        all_model_types.extend([models_type] * mean_synaptic_w.shape[0])  # Add model type for each score
        all_connection_types.extend([connection_types_list[connection_idx]] * mean_synaptic_w.shape[0])  # Add connection type for each score

# Create a DataFrame for easier plotting
data = pd.DataFrame({
    'Model Type': all_model_types,
    'Connection Types': all_connection_types,
    'Weights': all_weights
})

# Create a grouped boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Connection Types', y='Weights', hue='Model Type', 
            data=data, width=0.3, dodge=True) 
plt.title('Synaptic Weights by Connection Type and Model Type')
plt.xlabel('Connection Type')
plt.ylabel('Average Synaptic Weights')
plt.legend(title='Model Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.savefig('1C.eps', format='eps')

# %% [markdown]
# ## Plotting performance by trial type

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import scipy.io
import pandas as pd
from scipy import stats

models_type = 'good_models'
trials_types = ['+1', '-1']
lesion_connections_list = ['no lesion', 'I - I']
models_dir = '/scratch/spikeRNN/models/DMS_OSF/' # dir where all models are located

# Initialize lists to hold data
all_performance = []
all_trial_types = []
all_lesion_connections = []

# Loop through the model types and gather data
for trials_type in trials_types:
    model_performance = scipy.io.loadmat(f'{models_dir}{models_type}/{models_type}_trialtype_performance.mat')
    if trials_type == '+1':
        model_performance = model_performance['eval_perf_mean_plus']
    else:
        model_performance = model_performance['eval_perf_mean_minus']
    
    # Assuming model_performance is structured as (n_models, n_lesions)
    for lesion_idx in range(model_performance.shape[1]):
        all_performance.extend(model_performance[:, lesion_idx])  # Collect performance scores for the lesion type
        all_trial_types.extend([trials_type] * model_performance.shape[0])  # Add model type for each score
        all_lesion_connections.extend([lesion_connections_list[lesion_idx]] * model_performance.shape[0])  # Add lesion type for each score

# Create a DataFrame for easier plotting
data = pd.DataFrame({
    'Trial Type': all_trial_types,
    'Lesion Connection': all_lesion_connections,
    'Performance': all_performance
})

# Create a grouped boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Lesion Connection', y='Performance', hue='Trial Type', 
            data=data, width=0.3, dodge=True) 
plt.title('Model Performance by Lesion Connection and Trial Type')
plt.xlabel('Lesion Connection')
plt.ylabel('Performance')
plt.legend(title='Trial Type')
plt.xticks(rotation=45)
plt.tight_layout()

# Perform the Wilcoxon rank-sum test between model types for each lesion type
for i, connection in enumerate(lesion_connections_list):

        # Extract performance for both model types for the current lesion type
        group1 = data[(data['Lesion Connection'] == connection) & (data['Trial Type'] == '+1')]['Performance']
        group2 = data[(data['Lesion Connection'] == connection) & (data['Trial Type'] == '-1')]['Performance']
        
        # Perform the rank-sum test only if both groups have data
        if not group1.empty and not group2.empty:
            statistic, p_value = stats.ranksums(group1, group2)
            print(f'Comparing {connection} vs {connection}, p-value: {p_value}')

            # Determine significance level for annotation
            if p_value < 0.001:
                significance = '***'
            elif p_value < 0.01:
                significance = '**'
            elif p_value < 0.05:
                significance = '*'
            else:
                significance = ''

            # Get the x position for the current lesion connection
            x_pos = (lesion_connections_list.index(connection1) + lesion_connections_list.index(connection2))/2
            
            # Annotate the significance on the plot
            if significance:
                # Adjust y position for the annotation
                y_pos = max(data['Performance']) + 0.03  # Adjust this based on data
                ax.annotate(significance, 
                            xy=(x_pos, y_pos), 
                            ha='center', 
                            va='bottom',
                            fontsize=16) 

plt.show()
# Out:
# Comparing no lesion vs no lesion, p-value: 0.5072716597928832
# Comparing I - I vs I - I, p-value: 0.31878565272634973

# %%
ii_perf = np.vstack((group1, group2))
ii_perf.shape

plt.figure()
plt.plot(ii_perf)
plt.xlabel('Stimulus')
plt.ylabel('Performance')
plt.xticks([0, 1], ['+1', '-1'])
plt.show()

# %%
plt.figure()
plt.scatter(group1, group2)
plt.xlabel('Performance on +1 trials')
plt.ylabel('Performance on -1 trials')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.title('Lesioned Performance')
plt.show()

# %%
plt.figure()
sns.boxplot(np.array(group1) - np.array(group2))
plt.xlabel('Lesion I-I Connection')
plt.ylabel('Performance Difference between +1 and -1 trials')
plt.show()

# %% [markdown]
# how about for non-lesioned?

# %%
group1_intact = data[(data['Lesion Connection'] == 'no lesion') & (data['Trial Type'] == '+1')]['Performance']
group2_intact = data[(data['Lesion Connection'] == 'no lesion') & (data['Trial Type'] == '-1')]['Performance']

intact_perf = np.vstack((group1_intact, group2_intact))

# %%
plt.figure()
plt.plot(intact_perf)
plt.xlabel('Stimulus')
plt.ylabel('Performance')
plt.xticks([0, 1], ['+1', '-1'])
plt.show()

# %%
plt.figure()
plt.scatter(group1_intact, group2_intact)
plt.xlabel('Performance on +1 trials')
plt.ylabel('Performance on -1 trials')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.title('Intact Performance')
plt.show()

# %%
# make boxplot with difference btwn groups for both intact and lesioned
plt.figure()
intact_diff = (np.array(group1_intact) - np.array(group2_intact))
lesioned_diff = (np.array(group1) - np.array(group2))
sns.boxplot([intact_diff, lesioned_diff])
plt.xticks([0, 1], ['Intact', 'Lesioned'])
plt.ylabel('Difference')
plt.title('Performance Difference btwn +1 and -1 trials')
plt.show()

# %%
plt.figure()
sns.boxplot(np.array(group1) - np.array(group2))
plt.xlabel('Lesion I-I Connection')
plt.ylabel('Performance Difference between +1 and -1 trials')
plt.show()
